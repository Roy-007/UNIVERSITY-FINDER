# %%
import matplotlib.ticker as ticker
from urllib.request import urlopen
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
from datetime import datetime
import seaborn as sns
import pandas as pd
import numpy as np
import requests
import time
import re

# %%
def get_data(pageNo):  
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    r = requests.get('https://www.apartments.com/hoboken-nj/?bb=5m3ls266vHu5y0lF')
    content = r.content
    soup = BeautifulSoup(content)
    #print(soup)

    alls = []
    for d in soup.findAll('div', attrs={'class':'placardContainer'}):
        
        name = d.find('span', attrs={'class':'js-placardTitle title'})
        location = d.find('div', attrs={'class':'property-address js-url'})
        rating = d.find('div', attrs={'class':'price-rangel'})
        scores = d.find('div', attrs={'class':'bed-range'})
        price = d.find('div', attrs={'class':'availability'})

        all1=[]

        if name is not None:
            #print(n[0]['alt'])
            all1.append(name.text)
        else:
            all1.append("N/A")

        if location is not None:
            all1.append(location.text)
        else:    
            all1.append('N/A')

        if rating is not None:
            #print(rating.text)
            all1.append(rating.text)
        else:
            all1.append('N/A')

        if scores is not None:
            #print(price.text)
            all1.append(scores.text)
        else:
            all1.append('-*-')     
            
        if price is not None:
            print(price.text)
            all1.append(price.text)
        else:
            all1.append('-*-')
        alls.append(all1)    
    return alls

# %%
results = []
for i in range(1):
    results.append(get_data(i))
flatten = lambda l: [item for sublist in l for item in sublist]
df = pd.DataFrame(flatten(results),columns=['UNIVERSITY NAME','LOCATION','RATING','SCORES','PRICE'])
df.to_csv('housedata.csv', index=False, encoding='utf-8')

# %%
df = pd.read_csv("housedata.csv")
df.shape

# %%
df.head(20)
# Out:
# Empty DataFrame
# Columns: [UNIVERSITY NAME, LOCATION, RATING, SCORES]
# Index: []

# %%
<div id="placardContainer" class="placardContainer" data-analytics-profiletype="Unknown">
    <ul>

<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-diamond" data-listingid="2r4fzgc" data-url="https://www.apartments.com/hoboken-south-waterfront-hoboken-nj/2r4fzgc/" data-ck="7tm92xz">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/hoboken-south-waterfront-hoboken-nj/2r4fzgc/">
                    
                    <div class="property-title" title="Hoboken South Waterfront, Hoboken, NJ"><span class="js-placardTitle title">Hoboken South Waterfront</span></div>
                    <div class="property-address js-url" title="333 River St, Hoboken, NJ 07030">333 River St, Hoboken, NJ 07030</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/hoboken-south-waterfront-hoboken-nj/2r4fzgc/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="Ironstate Development Company" style="background-image: url(https://images1.apartments.com/i2/Y_wkGQnL6-VodCkfvM7sLeSKuJn-trZt8WyJ89Isato/110/ironstate-development-company-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">75</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " title="Building Photo - Hoboken South Waterfront" style="background-image: url(&quot;https://images1.apartments.com/i2/-uD5TzLgUBIXFYmyLOUrJetbC7RFxteZgXtV622o6WE/115/hoboken-south-waterfront-hoboken-nj-building-photo.jpg&quot;);">
		</div>
	</div>
</div>

<div class="placardBanner">
            <button type="button" class="virtualTour" title="See Hoboken South Waterfront in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/hoboken-south-waterfront-hoboken-nj/2r4fzgc/#photos">75 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/hoboken-south-waterfront-hoboken-nj/2r4fzgc/#3dtours">Virtual Tour</a></li>
                                                                    </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="lastUpdated">
								<i class="rotateRightIcon" title="Last Updated"></i>
						<span>4 hrs Ago</span>
				</span>
</span>

                                <div class="specials" data-specials-label="1 Month Free">
                                    1 Month Free<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip">This property is offering 1 month free rent.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,030 - 5,495</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">Studio - 3 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>

                            <div class="property-amenities">
                                            <span>Dog Friendly</span>
                                            <span>Cat Friendly</span>
                                            <span>Air Conditioning</span>
                                            <span>Washer/Dryer - In Unit</span>
                                            <span>Dishwasher</span>

                            </div>

                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:2014794462">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>201-479-4462</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-diamond" data-listingid="qfymzkz" data-url="https://www.apartments.com/7-seventy-house-hoboken-nj/qfymzkz/" data-ck="dv0gtnl">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/7-seventy-house-hoboken-nj/qfymzkz/">
                    
                    <div class="property-title" title="7 Seventy House, Hoboken, NJ"><span class="js-placardTitle title">7 Seventy House</span></div>
                    <div class="property-address js-url" title="770 Jackson St, Hoboken, NJ 07030">770 Jackson St, Hoboken, NJ 07030</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/7-seventy-house-hoboken-nj/qfymzkz/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="Greystar" style="background-image: url(https://images1.apartments.com/i2/0zTY3x768ega_7erB5uV8azPJH_HbNXQ_1ODNJEv660/110/greystar-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">58</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " title="Building Photo - 7 Seventy House" style="background-image: url(&quot;https://images1.apartments.com/i2/UtowHsmWzUuH_pDHEbwc_HoGiLLU7qjjOVwfaIRr-gU/115/7-seventy-house-hoboken-nj-building-photo.jpg&quot;);">
		</div>
	</div>
</div>

<div class="placardBanner">
        <button type="button" class="videoPlay" title="Watch 7 Seventy House Video" data-video="https://vapi.costargroup.com/video/play/0m5g6c?source=42" data-videokey="0m5g6c" data-datasource="42">
            <i class="playVideoPlacardIcon"></i>
        </button>
            <button type="button" class="virtualTour" title="See 7 Seventy House in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/7-seventy-house-hoboken-nj/qfymzkz/#photos">58 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/7-seventy-house-hoboken-nj/qfymzkz/#3dtours">Virtual Tour</a></li>
                                                                            <li><a href="https://www.apartments.com/7-seventy-house-hoboken-nj/qfymzkz/#videos">Videos</a></li>
                                </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="new">
						<i class="alertLightningBoltIcon" title="New"></i>
						<span>New</span>
				</span>
</span>

                                <div class="specials" data-specials-label="2 Months Free">
                                    2 Months Free<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip" style="top: 0px; right: 0px;">This property is offering 2 months free rent.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,395 - 4,400</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">Studio - 3 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>

                            <div class="property-amenities">
                                            <span>Dog Friendly</span>
                                            <span>Cat Friendly</span>
                                            <span>Air Conditioning</span>
                                            <span>Dishwasher</span>
                                            <span>Parking</span>

                            </div>

                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:7327091592">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>732-709-1592</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-diamond" data-listingid="4qsh3ch" data-url="https://www.apartments.com/courtyard-at-jefferson-hoboken-nj/4qsh3ch/" data-ck="dv0gtnl">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/courtyard-at-jefferson-hoboken-nj/4qsh3ch/">
                    
                    <div class="property-title" title="Courtyard at Jefferson, Hoboken, NJ"><span class="js-placardTitle title">Courtyard at Jefferson</span></div>
                    <div class="property-address js-url" title="800 Jefferson St, Hoboken, NJ 07030">800 Jefferson St, Hoboken, NJ 07030</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/courtyard-at-jefferson-hoboken-nj/4qsh3ch/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="Greystar" style="background-image: url(https://images1.apartments.com/i2/0zTY3x768ega_7erB5uV8azPJH_HbNXQ_1ODNJEv660/110/greystar-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">25</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " title="Building Photo - Courtyard at Jefferson" style="background-image: url(&quot;https://images1.apartments.com/i2/Dp0yh-Ab-FfC3WcSt1IqVWO8EKZn1PwDA1oOWLH8iLg/115/courtyard-at-jefferson-hoboken-nj-building-photo.jpg&quot;);">
		</div>
	</div>
</div>

<div class="placardBanner">
            <button type="button" class="virtualTour" title="See Courtyard at Jefferson in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/courtyard-at-jefferson-hoboken-nj/4qsh3ch/#photos">25 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/courtyard-at-jefferson-hoboken-nj/4qsh3ch/#3dtours">Virtual Tour</a></li>
                                                                    </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="new">
						<i class="alertLightningBoltIcon" title="New"></i>
						<span>New</span>
				</span>
</span>

                                <div class="specials" data-specials-label="Specials">
                                    Specials<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip">This property has a special promotion.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,581 - 4,476</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">1-3 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>

                            <div class="property-amenities">
                                            <span>Dog Friendly</span>
                                            <span>Cat Friendly</span>
                                            <span>Air Conditioning</span>
                                            <span>Washer/Dryer - In Unit</span>
                                            <span>Dishwasher</span>

                            </div>

                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:2013992726">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>201-399-2726</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-diamond" data-listingid="1wkgy56" data-url="https://www.apartments.com/hamilton-cove-weehawken-nj/1wkgy56/" data-ck="dv0gtnl">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/hamilton-cove-weehawken-nj/1wkgy56/">
                    
                    <div class="property-title" title="Hamilton Cove, Weehawken, NJ"><span class="js-placardTitle title">Hamilton Cove</span></div>
                    <div class="property-address js-url" title="800 Harbor Blvd, Weehawken, NJ 07086">800 Harbor Blvd, Weehawken, NJ 07086</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/hamilton-cove-weehawken-nj/1wkgy56/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="Greystar Real Estate Partners" style="background-image: url(https://images1.apartments.com/i2/0zTY3x768ega_7erB5uV8azPJH_HbNXQ_1ODNJEv660/110/greystar-real-estate-partners-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">65</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " title="Building Photo - Hamilton Cove" style="background-image: url(&quot;https://images1.apartments.com/i2/AjNlqR1ZgUuSh6BmpkfaUZhnyh9bfxDUP1NwVbGOe_0/115/hamilton-cove-weehawken-nj-building-photo.jpg&quot;);">
		</div>
	</div>
</div>

<div class="placardBanner">
            <button type="button" class="virtualTour" title="See Hamilton Cove in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/hamilton-cove-weehawken-nj/1wkgy56/#photos">65 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/hamilton-cove-weehawken-nj/1wkgy56/#3dtours">Virtual Tour</a></li>
                                                                    </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="new">
						<i class="alertLightningBoltIcon" title="New"></i>
						<span>New</span>
				</span>
</span>

                                <div class="specials" data-specials-label="2 Months Free">
                                    2 Months Free<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip">This property is offering 2 months free rent.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,355 - 7,800</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">Studio - 3 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>

                            <div class="property-amenities">
                                            <span>Dog Friendly</span>
                                            <span>Cat Friendly</span>
                                            <span>Air Conditioning</span>
                                            <span>Washer/Dryer - In Unit</span>
                                            <span>Dishwasher</span>

                            </div>

                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:2013993483">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>201-399-3483</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-diamond" data-listingid="ysk27ws" data-url="https://www.apartments.com/the-lexington-hoboken-nj/ysk27ws/" data-ck="yjrkg4v">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/the-lexington-hoboken-nj/ysk27ws/">
                    
                    <div class="property-title" title="The Lexington, Hoboken, NJ"><span class="js-placardTitle title">The Lexington</span></div>
                    <div class="property-address js-url" title="619 Adams St, Hoboken, NJ 07030">619 Adams St, Hoboken, NJ 07030</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/the-lexington-hoboken-nj/ysk27ws/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="JDA Group LLC" style="background-image: url(https://images1.apartments.com/i2/Pf5ROx878yEGWQo-TFhcH31q7imcNEhIKjaVvRN8WEk/110/jda-group-llc-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">39</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/qk8S4bD7OAhsczvUsSxcFCJjZaPkmsPUgSVJpTDtef8/115/the-lexington-hoboken-nj-building-photo.jpg" title="Building Photo - The Lexington">
		</div>
	</div>
</div>

<div class="placardBanner">
        <button type="button" class="videoPlay" title="Watch The Lexington Video" data-video="https://vapi.costargroup.com/video/play/6v9j1k?source=42" data-videokey="6v9j1k" data-datasource="42">
            <i class="playVideoPlacardIcon"></i>
        </button>
            <button type="button" class="virtualTour" title="See The Lexington in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/the-lexington-hoboken-nj/ysk27ws/#photos">39 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/the-lexington-hoboken-nj/ysk27ws/#3dtours">Virtual Tour</a></li>
                                                                            <li><a href="https://www.apartments.com/the-lexington-hoboken-nj/ysk27ws/#videos">Videos</a></li>
                                </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header no-specials">

<span class="listingFreshness">
				<span class="lastUpdated">
								<i class="rotateRightIcon" title="Last Updated"></i>
						<span>6 hrs Ago</span>
				</span>
</span>

                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,595 - 4,250</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">1-2 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>

                            <div class="property-amenities">
                                            <span>Air Conditioning</span>
                                            <span>Washer/Dryer - In Unit</span>
                                            <span>Dishwasher</span>
                                            <span>Parking</span>
                                            <span>Fitness Center</span>

                            </div>

                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:8442813583">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>844-281-3583</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-diamond" data-listingid="68852nt" data-url="https://www.apartments.com/observer-park-hoboken-nj/68852nt/" data-ck="dv0gtnl">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/observer-park-hoboken-nj/68852nt/">
                    
                    <div class="property-title" title="Observer Park, Hoboken, NJ"><span class="js-placardTitle title">Observer Park</span></div>
                    <div class="property-address js-url" title="51 Garden St, Hoboken, NJ 07030">51 Garden St, Hoboken, NJ 07030</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/observer-park-hoboken-nj/68852nt/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="Greystar Real Estate Partners" style="background-image: url(https://images1.apartments.com/i2/0zTY3x768ega_7erB5uV8azPJH_HbNXQ_1ODNJEv660/110/greystar-real-estate-partners-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">47</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/E5LHWeYXV3SP7muj_gllmFkvEXuh2yaHEa0Yn9wKRaQ/115/observer-park-hoboken-nj-building-photo.jpg" title="Building Photo - Observer Park">
		</div>
	</div>
</div>

<div class="placardBanner">
            <button type="button" class="virtualTour" title="See Observer Park in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/observer-park-hoboken-nj/68852nt/#photos">47 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/observer-park-hoboken-nj/68852nt/#3dtours">Virtual Tour</a></li>
                                                                    </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="new">
						<i class="alertLightningBoltIcon" title="New"></i>
						<span>New</span>
				</span>
</span>

                                <div class="specials" data-specials-label="2 Months Free">
                                    2 Months Free<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip">This property is offering 2 months free rent.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,344 - 5,000</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">1-3 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>

                            <div class="property-amenities">
                                            <span>Dog Friendly</span>
                                            <span>Cat Friendly</span>
                                            <span>Air Conditioning</span>
                                            <span>Washer/Dryer - In Unit</span>
                                            <span>Dishwasher</span>

                            </div>

                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:8443725662">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>844-372-5662</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-diamond" data-listingid="wmw15hk" data-url="https://www.apartments.com/the-rivington-hoboken-nj/wmw15hk/" data-ck="16qxml6">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/the-rivington-hoboken-nj/wmw15hk/">
                    
                    <div class="property-title" title="The Rivington, Hoboken, NJ"><span class="js-placardTitle title">The Rivington</span></div>
                    <div class="property-address js-url" title="1130-1133 Grand St, Hoboken, NJ 07030">1130-1133 Grand St, Hoboken, NJ 07030</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/the-rivington-hoboken-nj/wmw15hk/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="Equity Residential" style="background-image: url(https://images1.apartments.com/i2/PQeeeknIrB-yjSoBLCeEL4NIpx6uZSGYAb30QfbVxJM/110/equity-residential-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">49</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/kMh7yKESrjcVky8lzg9myTiruwVmj8GHCouuXnmcy0U/115/the-rivington-hoboken-nj-exterior.jpg" title="Exterior - The Rivington">
		</div>
	</div>
</div>

<div class="placardBanner">
        <button type="button" class="videoPlay" title="Watch The Rivington Video" data-video="https://vapi.costargroup.com/video/play/0l8v0y?source=42" data-videokey="0l8v0y" data-datasource="42">
            <i class="playVideoPlacardIcon"></i>
        </button>
            <button type="button" class="virtualTour" title="See The Rivington in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/the-rivington-hoboken-nj/wmw15hk/#photos">49 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/the-rivington-hoboken-nj/wmw15hk/#3dtours">Virtual Tour</a></li>
                                                                            <li><a href="https://www.apartments.com/the-rivington-hoboken-nj/wmw15hk/#videos">Videos</a></li>
                                </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="lastUpdated">
								<i class="rotateRightIcon" title="Last Updated"></i>
						<span>10 hrs Ago</span>
				</span>
</span>

                                <div class="specials" data-specials-label="Specials">
                                    Specials<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip">This property has a special promotion.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$3,290 - 3,542</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">2 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>

                            <div class="property-amenities">
                                            <span>Dog Friendly</span>
                                            <span>Cat Friendly</span>
                                            <span>Air Conditioning</span>
                                            <span>Washer/Dryer - In Unit</span>
                                            <span>Dishwasher</span>

                            </div>

                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:8448487994">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>844-848-7994</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-diamond" data-listingid="rdt8tb0" data-url="https://www.apartments.com/clinton-square-hoboken-nj/rdt8tb0/" data-ck="ewmdpfq">
        <header class="placard-header ">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/clinton-square-hoboken-nj/rdt8tb0/">
                    
                    <div class="property-title" title="Clinton Square, Hoboken, NJ"><span class="js-placardTitle title">Clinton Square</span></div>
                    <div class="property-address js-url" title="101 Clinton St, Hoboken, NJ 07030">101 Clinton St, Hoboken, NJ 07030</div>
                </a>
            </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">31</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/w5rLskh1zKC2dlBpvYF22aKfow3T8grolnk8P1te8YY/115/clinton-square-hoboken-nj-interior-photo.jpg" title="Interior Photo - Clinton Square">
		</div>
	</div>
</div>

<div class="placardBanner">
        <button type="button" class="videoPlay" title="Watch Clinton Square Video" data-video="https://vapi.costargroup.com/video/play/6e1i3u?source=42" data-videokey="6e1i3u" data-datasource="42">
            <i class="playVideoPlacardIcon"></i>
        </button>
            <button type="button" class="virtualTour" title="See Clinton Square in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/clinton-square-hoboken-nj/rdt8tb0/#photos">31 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/clinton-square-hoboken-nj/rdt8tb0/#3dtours">Virtual Tour</a></li>
                                                                            <li><a href="https://www.apartments.com/clinton-square-hoboken-nj/rdt8tb0/#videos">Videos</a></li>
                                </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="lastUpdated">
								<i class="rotateRightIcon" title="Last Updated"></i>
						<span>2 days Ago</span>
				</span>
</span>

                                <div class="specials" data-specials-label="Specials">
                                    Specials<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip">This property has a special promotion.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,650 - 3,150</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">1-2 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>

                            <div class="property-amenities">
                                            <span>Air Conditioning</span>
                                            <span>Dishwasher</span>
                                            <span>Parking</span>
                                            <span>Wheelchair Access</span>

                            </div>

                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:5512031117">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>551-203-1117</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-diamond" data-listingid="wl5mpsh" data-url="https://www.apartments.com/grand-adams-hoboken-nj/wl5mpsh/" data-ck="pzkzqbv">
        <header class="placard-header ">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/grand-adams-hoboken-nj/wl5mpsh/">
                    
                    <div class="property-title" title="Grand Adams, Hoboken, NJ"><span class="js-placardTitle title">Grand Adams</span></div>
                    <div class="property-address js-url" title="300-320 Grand St, Hoboken, NJ 07030">300-320 Grand St, Hoboken, NJ 07030</div>
                </a>
            </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">104</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/BgZtw_wKUdT5jnawo4XoKQ6lVJVhkp9hZXUSW3T4fwk/115/grand-adams-hoboken-nj-building-photo.jpg" title="Building Photo - Grand Adams">
		</div>
	</div>
</div>

<div class="placardBanner">
        <button type="button" class="videoPlay" title="Watch Grand Adams Video" data-video="https://vapi.costargroup.com/video/play/5u4t1b?source=42" data-videokey="5u4t1b" data-datasource="42">
            <i class="playVideoPlacardIcon"></i>
        </button>
            <button type="button" class="virtualTour" title="See Grand Adams in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/grand-adams-hoboken-nj/wl5mpsh/#photos">104 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/grand-adams-hoboken-nj/wl5mpsh/#3dtours">Virtual Tour</a></li>
                                                                            <li><a href="https://www.apartments.com/grand-adams-hoboken-nj/wl5mpsh/#videos">Videos</a></li>
                                </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="lastUpdated">
								<i class="rotateRightIcon" title="Last Updated"></i>
						<span>1 wk Ago</span>
				</span>
</span>

                                <div class="specials" data-specials-label="2 Months Free">
                                    2 Months Free<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip">This property is offering 2 months free rent.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$1,760 - 4,569</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">Studio - 3 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>

                            <div class="property-amenities">
                                            <span>Air Conditioning</span>
                                            <span>Washer/Dryer - In Unit</span>
                                            <span>Dishwasher</span>
                                            <span>Parking</span>

                            </div>

                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:8558895427">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>855-889-5427</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-diamond" data-listingid="sr8vbt5" data-url="https://www.apartments.com/cast-iron-lofts-jersey-city-nj/sr8vbt5/" data-ck="dv0gtnl">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/cast-iron-lofts-jersey-city-nj/sr8vbt5/">
                    
                    <div class="property-title" title="Cast Iron Lofts, Jersey City, NJ"><span class="js-placardTitle title">Cast Iron Lofts</span></div>
                    <div class="property-address js-url" title="837 Jersey Ave, Jersey City, NJ 07310">837 Jersey Ave, Jersey City, NJ 07310</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/cast-iron-lofts-jersey-city-nj/sr8vbt5/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="Greystar" style="background-image: url(https://images1.apartments.com/i2/0zTY3x768ega_7erB5uV8azPJH_HbNXQ_1ODNJEv660/110/greystar-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">65</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/VoXblKl4W_MAC3tkixTWoOLgztbrLC5ZhVXQSp9ULH4/115/cast-iron-lofts-jersey-city-nj-building-photo.jpg" title="Building Photo - Cast Iron Lofts">
		</div>
	</div>
</div>

<div class="placardBanner">
        <button type="button" class="videoPlay" title="Watch Cast Iron Lofts Video" data-video="https://vapi.costargroup.com/video/play/0s9i6m?source=42" data-videokey="0s9i6m" data-datasource="42">
            <i class="playVideoPlacardIcon"></i>
        </button>
            <button type="button" class="virtualTour" title="See Cast Iron Lofts in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/cast-iron-lofts-jersey-city-nj/sr8vbt5/#photos">65 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/cast-iron-lofts-jersey-city-nj/sr8vbt5/#3dtours">Virtual Tour</a></li>
                                                                            <li><a href="https://www.apartments.com/cast-iron-lofts-jersey-city-nj/sr8vbt5/#videos">Videos</a></li>
                                </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="new">
						<i class="alertLightningBoltIcon" title="New"></i>
						<span>New</span>
				</span>
</span>

                                <div class="specials" data-specials-label="Specials">
                                    Specials<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip">This property has a special promotion.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,282 - 5,078</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">Studio - 3 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>

                            <div class="property-amenities">
                                            <span>Dog Friendly</span>
                                            <span>Cat Friendly</span>
                                            <span>Air Conditioning</span>
                                            <span>Washer/Dryer - In Unit</span>
                                            <span>Dishwasher</span>

                            </div>

                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:8446958695">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>844-695-8695</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-diamond" data-listingid="51mye7p" data-url="https://www.apartments.com/sawyer-jersey-city-nj/51mye7p/" data-ck="j4nm4e7">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/sawyer-jersey-city-nj/51mye7p/">
                    
                    <div class="property-title" title="Sawyer, Jersey City, NJ"><span class="js-placardTitle title">Sawyer</span></div>
                    <div class="property-address js-url" title="39 New York Ave, Jersey City, NJ 07307">39 New York Ave, Jersey City, NJ 07307</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/sawyer-jersey-city-nj/51mye7p/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="The NRP Group, LLC" style="background-image: url(https://images1.apartments.com/i2/gj7VorEoyjCI7IRaTidPEMievPxJmF4i6atxUwfyhLk/110/the-nrp-group-llc-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">12</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/FkiX2P_7d13HwMXhByK3pFpKtOwCyBwZgb8YNoNtsok/115/sawyer-jersey-city-nj-interior-photo.jpg" title="Interior Photo - Sawyer">
		</div>
	</div>
</div>

<div class="placardBanner">
    </div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/sawyer-jersey-city-nj/51mye7p/#photos">12 Photos</a></li>
                                                                                                        </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header no-specials">

<span class="listingFreshness">
				<span class="lastUpdated">
								<i class="rotateRightIcon" title="Last Updated"></i>
						<span>4 hrs Ago</span>
				</span>
</span>

                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,135 - 4,055</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">Studio - 2 Bed</div>
                            <div class="availability">Avail. Jun 01</div>
                        </div>

                            <div class="property-amenities">
                                            <span>Parking</span>

                            </div>

                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:8443749876">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>844-374-9876</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-diamond" data-listingid="xmrsd9n" data-url="https://www.apartments.com/one-ten-jersey-city-nj/xmrsd9n/" data-ck="mhmdhsj">
        <header class="placard-header ">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/one-ten-jersey-city-nj/xmrsd9n/">
                    
                    <div class="property-title" title="One Ten, Jersey City, NJ"><span class="js-placardTitle title">One Ten</span></div>
                    <div class="property-address js-url" title="110 Hoboken Ave, Jersey City, NJ 07310">110 Hoboken Ave, Jersey City, NJ 07310</div>
                </a>
            </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">39</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/aBCf2CdpJNorL5VNDhCwABKinHGz_1tKMRo7zYEi7tE/115/one-ten-jersey-city-nj-building-photo.jpg" title="Building Photo - One Ten">
		</div>
	</div>
</div>

<div class="placardBanner">
    </div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/one-ten-jersey-city-nj/xmrsd9n/#photos">39 Photos</a></li>
                                                                                                        </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header no-specials">

<span class="listingFreshness">
				<span class="new">
						<i class="alertLightningBoltIcon" title="New"></i>
						<span>New</span>
				</span>
</span>

                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,050 - 3,925</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">Studio - 2 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>

                            <div class="property-amenities">
                                            <span>Washer/Dryer - In Unit</span>
                                            <span>Dishwasher</span>
                                            <span>Parking</span>
                                            <span>Fitness Center</span>

                            </div>

                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:2018973848">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>201-897-3848</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-diamond" data-listingid="9qse6q7" data-url="https://www.apartments.com/100-house-jersey-city-nj/9qse6q7/" data-ck="mhmdhsj">
        <header class="placard-header ">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/100-house-jersey-city-nj/9qse6q7/">
                    
                    <div class="property-title" title="100 House, Jersey City, NJ"><span class="js-placardTitle title">100 House</span></div>
                    <div class="property-address js-url" title="100 Hoboken Ave, Jersey City, NJ 07310">100 Hoboken Ave, Jersey City, NJ 07310</div>
                </a>
            </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">64</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/Cw0NRuVfYNMOAt4lTE68r8IVfS3XbSUJD5KegS7sQ8w/115/100-house-jersey-city-nj-building-photo.jpg" title="Building Photo - 100 House">
		</div>
	</div>
</div>

<div class="placardBanner">
        <button type="button" class="videoPlay" title="Watch 100 House Video" data-video="https://vapi.costargroup.com/video/play/5t2i3b?source=42" data-videokey="5t2i3b" data-datasource="42">
            <i class="playVideoPlacardIcon"></i>
        </button>
            <button type="button" class="virtualTour" title="See 100 House in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/100-house-jersey-city-nj/9qse6q7/#photos">64 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/100-house-jersey-city-nj/9qse6q7/#3dtours">Virtual Tour</a></li>
                                                                            <li><a href="https://www.apartments.com/100-house-jersey-city-nj/9qse6q7/#videos">Videos</a></li>
                                </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="lastUpdated">
								<i class="rotateRightIcon" title="Last Updated"></i>
						<span>1 day Ago</span>
				</span>
</span>

                                <div class="specials" data-specials-label="2 Months Free">
                                    2 Months Free<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip">This property is offering 2 months free rent.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,150 - 2,295</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">Studio - 2 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>

                            <div class="property-amenities">
                                            <span>Dog Friendly</span>
                                            <span>Cat Friendly</span>
                                            <span>Air Conditioning</span>
                                            <span>Washer/Dryer - In Unit</span>
                                            <span>Dishwasher</span>

                            </div>

                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:8776545955">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>877-654-5955</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-diamond" data-listingid="zg2v3nz" data-url="https://www.apartments.com/gateway-at-park-ave-weehawken-nj/zg2v3nz/" data-ck="xcwxhsn">
        <header class="placard-header ">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/gateway-at-park-ave-weehawken-nj/zg2v3nz/">
                    
                    <div class="property-title" title="Gateway at Park Ave, Weehawken, NJ"><span class="js-placardTitle title">Gateway at Park Ave</span></div>
                    <div class="property-address js-url" title="1700 Park Ave, Weehawken, NJ 07086">1700 Park Ave, Weehawken, NJ 07086</div>
                </a>
            </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">55</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/Hu3RimnEgjujfW4Hd4acAC7wl4j2qMDJRNWRcyQBgUU/115/gateway-at-park-ave-weehawken-nj-building-photo.jpg" title="Building Photo - Gateway at Park Ave">
		</div>
	</div>
</div>

<div class="placardBanner">
        <button type="button" class="videoPlay" title="Watch Gateway at Park Ave Video" data-video="https://vapi.costargroup.com/video/play/6y3k2e?source=42" data-videokey="6y3k2e" data-datasource="42">
            <i class="playVideoPlacardIcon"></i>
        </button>
            <button type="button" class="virtualTour" title="See Gateway at Park Ave in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/gateway-at-park-ave-weehawken-nj/zg2v3nz/#photos">55 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/gateway-at-park-ave-weehawken-nj/zg2v3nz/#3dtours">Virtual Tour</a></li>
                                                                            <li><a href="https://www.apartments.com/gateway-at-park-ave-weehawken-nj/zg2v3nz/#videos">Videos</a></li>
                                </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header no-specials">

<span class="listingFreshness">
				<span class="lastUpdated">
								<i class="rotateRightIcon" title="Last Updated"></i>
						<span>1 wk Ago</span>
				</span>
</span>

                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,400 - 2,650</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">1-2 Bed</div>
                            <div class="availability">Avail. Mar 15</div>
                        </div>

                            <div class="property-amenities">
                                            <span>Dog Friendly</span>
                                            <span>Cat Friendly</span>
                                            <span>Air Conditioning</span>
                                            <span>Washer/Dryer - In Unit</span>
                                            <span>Dishwasher</span>

                            </div>

                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:2012051697">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>201-205-1697</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-platinum" data-listingid="9ry6077" data-url="https://www.apartments.com/juliana-hoboken-nj/9ry6077/" data-ck="dv0gtnl">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/juliana-hoboken-nj/9ry6077/">
                    
                    <div class="property-title" title="Juliana, Hoboken, NJ"><span class="js-placardTitle title">Juliana</span></div>
                    <div class="property-address js-url" title="600 Jackson St, Hoboken, NJ 07030">600 Jackson St, Hoboken, NJ 07030</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/juliana-hoboken-nj/9ry6077/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="Greystar" style="background-image: url(https://images1.apartments.com/i2/0zTY3x768ega_7erB5uV8azPJH_HbNXQ_1ODNJEv660/110/greystar-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">30</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/323h94fICA632qVfFQaf173ztk4EwLXijY8cjeEmA2U/115/juliana-hoboken-nj-building-photo.jpg" title="Building Photo - Juliana">
		</div>
	</div>
</div>

<div class="placardBanner">
            <button type="button" class="virtualTour" title="See Juliana in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/juliana-hoboken-nj/9ry6077/#photos">30 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/juliana-hoboken-nj/9ry6077/#3dtours">Virtual Tour</a></li>
                                                                    </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="new">
						<i class="alertLightningBoltIcon" title="New"></i>
						<span>New</span>
				</span>
</span>

                                <div class="specials" data-specials-label="Specials">
                                    Specials<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip">This property has a special promotion.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$3,120 - 5,134</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">1-3 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>


                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:8445942206">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>844-594-2206</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-platinum" data-listingid="stksey6" data-url="https://www.apartments.com/the-sovereign-at-the-shipyard-hoboken-nj/stksey6/" data-ck="7tm92xz">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/the-sovereign-at-the-shipyard-hoboken-nj/stksey6/">
                    
                    <div class="property-title" title="The Sovereign at The Shipyard, Hoboken, NJ"><span class="js-placardTitle title">The Sovereign at The Shipyard</span></div>
                    <div class="property-address js-url" title="2 14th St, Hoboken, NJ 07030">2 14th St, Hoboken, NJ 07030</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/the-sovereign-at-the-shipyard-hoboken-nj/stksey6/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="Ironstate Development Company" style="background-image: url(https://images1.apartments.com/i2/Y_wkGQnL6-VodCkfvM7sLeSKuJn-trZt8WyJ89Isato/110/ironstate-development-company-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">42</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/R2s0JyqhqMa5GWbppEMFfqvMKr0LlNC3py2laMRjGEI/115/the-sovereign-at-the-shipyard-hoboken-nj-building-photo.jpg" title="Building Photo - The Sovereign at The Shipyard">
		</div>
	</div>
</div>

<div class="placardBanner">
        <button type="button" class="videoPlay" title="Watch The Sovereign at The Shipyard Video" data-video="https://vapi.costargroup.com/video/play/2h4q2k?source=42" data-videokey="2h4q2k" data-datasource="42">
            <i class="playVideoPlacardIcon"></i>
        </button>
            <button type="button" class="virtualTour" title="See The Sovereign at The Shipyard in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/the-sovereign-at-the-shipyard-hoboken-nj/stksey6/#photos">42 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/the-sovereign-at-the-shipyard-hoboken-nj/stksey6/#3dtours">Virtual Tour</a></li>
                                                                            <li><a href="https://www.apartments.com/the-sovereign-at-the-shipyard-hoboken-nj/stksey6/#videos">Videos</a></li>
                                </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="lastUpdated">
								<i class="rotateRightIcon" title="Last Updated"></i>
						<span>5 hrs Ago</span>
				</span>
</span>

                                <div class="specials" data-specials-label="1 Month Free">
                                    1 Month Free<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip">This property is offering 1 month free rent.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$1,930 - 7,500</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">Studio - 4 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>


                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:8442454996">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>844-245-4996</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-platinum" data-listingid="45fy2sk" data-url="https://www.apartments.com/hudson-square-north-hoboken-nj/45fy2sk/" data-ck="7tm92xz">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/hudson-square-north-hoboken-nj/45fy2sk/">
                    
                    <div class="property-title" title="Hudson Square North, Hoboken, NJ"><span class="js-placardTitle title">Hudson Square North</span></div>
                    <div class="property-address js-url" title="235 Hudson St, Hoboken, NJ 07030">235 Hudson St, Hoboken, NJ 07030</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/hudson-square-north-hoboken-nj/45fy2sk/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="Ironstate Development Company" style="background-image: url(https://images1.apartments.com/i2/Y_wkGQnL6-VodCkfvM7sLeSKuJn-trZt8WyJ89Isato/110/ironstate-development-company-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">38</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/D7F3Hd1sVMnMngRo2AwV2SxVBoDDxwNSqtme_De7qIs/115/hudson-square-north-hoboken-nj-building-photo.jpg" title="Building Photo - Hudson Square North">
		</div>
	</div>
</div>

<div class="placardBanner">
            <button type="button" class="virtualTour" title="See Hudson Square North in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/hudson-square-north-hoboken-nj/45fy2sk/#photos">38 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/hudson-square-north-hoboken-nj/45fy2sk/#3dtours">Virtual Tour</a></li>
                                                                    </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="lastUpdated">
								<i class="rotateRightIcon" title="Last Updated"></i>
						<span>4 hrs Ago</span>
				</span>
</span>

                                <div class="specials" data-specials-label="Specials">
                                    Specials<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip">This property has a special promotion.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$1,870 - 4,205</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">1-3 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>


                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:2013802718">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>201-380-2718</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-platinum" data-listingid="xeqc8dn" data-url="https://www.apartments.com/park-garden-hoboken-nj/xeqc8dn/" data-ck="p2s139r">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/park-garden-hoboken-nj/xeqc8dn/">
                    
                    <div class="property-title" title="Park + Garden, Hoboken, NJ"><span class="js-placardTitle title">Park + Garden</span></div>
                    <div class="property-address js-url" title="1450 Garden St, Hoboken, NJ 07030">1450 Garden St, Hoboken, NJ 07030</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/park-garden-hoboken-nj/xeqc8dn/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="The Bozzuto Group" style="background-image: url(https://images1.apartments.com/i2/9dZAFlYvfgkw7kvg318zjTmviXLPJX8ZYB14Jl7Byzc/110/the-bozzuto-group-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">20</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/6FlUCvhUa97UEf7qjgYN-foyYeUYe0XrhcxkWdXnr5g/115/park-garden-hoboken-nj-building-photo.jpg" title="Building Photo - Park + Garden">
		</div>
	</div>
</div>

<div class="placardBanner">
        <button type="button" class="videoPlay" title="Watch Park + Garden Video" data-video="https://vapi.costargroup.com/video/play/7o1o5d?source=42" data-videokey="7o1o5d" data-datasource="42">
            <i class="playVideoPlacardIcon"></i>
        </button>
            <button type="button" class="virtualTour" title="See Park + Garden in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/park-garden-hoboken-nj/xeqc8dn/#photos">20 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/park-garden-hoboken-nj/xeqc8dn/#3dtours">Virtual Tour</a></li>
                                                                            <li><a href="https://www.apartments.com/park-garden-hoboken-nj/xeqc8dn/#videos">Videos</a></li>
                                </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="lastUpdated">
								<i class="rotateRightIcon" title="Last Updated"></i>
						<span>1 hr Ago</span>
				</span>
</span>

                                <div class="specials" data-specials-label="1 Month Free">
                                    1 Month Free<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip">This property is offering 1 month free rent.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$3,353 - 7,235</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">1-3 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>


                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:8447815668">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>844-781-5668</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-platinum" data-listingid="blm8ne9" data-url="https://www.apartments.com/77-park-avenue-hoboken-nj/blm8ne9/" data-ck="16qxml6">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/77-park-avenue-hoboken-nj/blm8ne9/">
                    
                    <div class="property-title" title="77 Park Avenue, Hoboken, NJ"><span class="js-placardTitle title">77 Park Avenue</span></div>
                    <div class="property-address js-url" title="77 Park Ave, Hoboken, NJ 07030">77 Park Ave, Hoboken, NJ 07030</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/77-park-avenue-hoboken-nj/blm8ne9/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="Equity Residential" style="background-image: url(https://images1.apartments.com/i2/PQeeeknIrB-yjSoBLCeEL4NIpx6uZSGYAb30QfbVxJM/110/equity-residential-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">34</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/6lNQdgyQUkGig1pBjOandwWzMnloAsUsQmjQE11cf9A/115/77-park-avenue-hoboken-nj-kitchen.jpg" title="Kitchen - 77 Park Avenue">
		</div>
	</div>
</div>

<div class="placardBanner">
            <button type="button" class="virtualTour" title="See 77 Park Avenue in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/77-park-avenue-hoboken-nj/blm8ne9/#photos">34 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/77-park-avenue-hoboken-nj/blm8ne9/#3dtours">Virtual Tour</a></li>
                                                                    </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="lastUpdated">
								<i class="rotateRightIcon" title="Last Updated"></i>
						<span>4 hrs Ago</span>
				</span>
</span>

                                <div class="specials" data-specials-label="1 Month Free">
                                    1 Month Free<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip">This property is offering 1 month free rent.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,309 - 4,767</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">Studio - 3 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>


                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:8557836311">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>855-783-6311</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-platinum" data-listingid="fd67k1t" data-url="https://www.apartments.com/vine-hoboken-nj/fd67k1t/" data-ck="dv0gtnl">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/vine-hoboken-nj/fd67k1t/">
                    
                    <div class="property-title" title="VINE, Hoboken, NJ"><span class="js-placardTitle title">VINE</span></div>
                    <div class="property-address js-url" title="900 Monroe St, Hoboken, NJ 07030">900 Monroe St, Hoboken, NJ 07030</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/vine-hoboken-nj/fd67k1t/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="Greystar" style="background-image: url(https://images1.apartments.com/i2/0zTY3x768ega_7erB5uV8azPJH_HbNXQ_1ODNJEv660/110/greystar-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">27</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/F94lu8-xDqeHCcTykbtDGvBwxc7duvyR9j0etfy-m7o/115/vine-hoboken-nj-building-photo.jpg" title="Building Photo - VINE">
		</div>
	</div>
</div>

<div class="placardBanner">
        <button type="button" class="videoPlay" title="Watch VINE Video" data-video="https://vapi.costargroup.com/video/play/7j0v7n?source=42" data-videokey="7j0v7n" data-datasource="42">
            <i class="playVideoPlacardIcon"></i>
        </button>
            <button type="button" class="virtualTour" title="See VINE in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/vine-hoboken-nj/fd67k1t/#photos">27 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/vine-hoboken-nj/fd67k1t/#3dtours">Virtual Tour</a></li>
                                                                            <li><a href="https://www.apartments.com/vine-hoboken-nj/fd67k1t/#videos">Videos</a></li>
                                </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="lastUpdated">
								<i class="rotateRightIcon" title="Last Updated"></i>
						<span>5 hrs Ago</span>
				</span>
</span>

                                <div class="specials" data-specials-label="2 Months Free">
                                    2 Months Free<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip">This property is offering 2 months free rent.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,572 - 29,622</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">1-3 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>


                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:8447402857">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>844-740-2857</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-platinum" data-listingid="ns17sgp" data-url="https://www.apartments.com/1000-jefferson-street-apartments-hoboken-nj/ns17sgp/" data-ck="dv0gtnl">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/1000-jefferson-street-apartments-hoboken-nj/ns17sgp/">
                    
                    <div class="property-title" title="1000 Jefferson Street Apartments, Hoboken, NJ"><span class="js-placardTitle title">1000 Jefferson Street Apartments</span></div>
                    <div class="property-address js-url" title="1000 Jefferson St, Hoboken, NJ 07030">1000 Jefferson St, Hoboken, NJ 07030</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/1000-jefferson-street-apartments-hoboken-nj/ns17sgp/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="Greystar Real Estate Partners" style="background-image: url(https://images1.apartments.com/i2/0zTY3x768ega_7erB5uV8azPJH_HbNXQ_1ODNJEv660/110/greystar-real-estate-partners-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">24</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/MwL2BHEmKHFvCkC9qlroNtt4_pqLOs65InGhWkDtBXo/115/1000-jefferson-street-apartments-hoboken-nj-building-photo.jpg" title="Building Photo - 1000 Jefferson Street Apartments">
		</div>
	</div>
</div>

<div class="placardBanner">
        <button type="button" class="videoPlay" title="Watch 1000 Jefferson Street Apartments Video" data-video="https://vapi.costargroup.com/video/play/6n5n6s?source=42" data-videokey="6n5n6s" data-datasource="42">
            <i class="playVideoPlacardIcon"></i>
        </button>
            <button type="button" class="virtualTour" title="See 1000 Jefferson Street Apartments in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/1000-jefferson-street-apartments-hoboken-nj/ns17sgp/#photos">24 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/1000-jefferson-street-apartments-hoboken-nj/ns17sgp/#3dtours">Virtual Tour</a></li>
                                                                            <li><a href="https://www.apartments.com/1000-jefferson-street-apartments-hoboken-nj/ns17sgp/#videos">Videos</a></li>
                                </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="new">
						<i class="alertLightningBoltIcon" title="New"></i>
						<span>New</span>
				</span>
</span>

                                <div class="specials" data-specials-label="1 Month Free">
                                    1 Month Free<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip">This property is offering 1 month free rent.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,525 - 4,630</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">1-3 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>


                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:8442974351">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>844-297-4351</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-platinum" data-listingid="d77c95l" data-url="https://www.apartments.com/hudson-square-south-hoboken-nj/d77c95l/" data-ck="7tm92xz">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/hudson-square-south-hoboken-nj/d77c95l/">
                    
                    <div class="property-title" title="Hudson Square South, Hoboken, NJ"><span class="js-placardTitle title">Hudson Square South</span></div>
                    <div class="property-address js-url" title="205 Hudson St, Hoboken, NJ 07030">205 Hudson St, Hoboken, NJ 07030</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/hudson-square-south-hoboken-nj/d77c95l/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="Ironstate Development Company" style="background-image: url(https://images1.apartments.com/i2/Y_wkGQnL6-VodCkfvM7sLeSKuJn-trZt8WyJ89Isato/110/ironstate-development-company-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">37</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/tJIzi_R2t98r-0pHCNzJNd7gIN1FMRE4MlWqxJW5K9A/115/hudson-square-south-hoboken-nj-building-photo.jpg" title="Building Photo - Hudson Square South">
		</div>
	</div>
</div>

<div class="placardBanner">
            <button type="button" class="virtualTour" title="See Hudson Square South in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/hudson-square-south-hoboken-nj/d77c95l/#photos">37 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/hudson-square-south-hoboken-nj/d77c95l/#3dtours">Virtual Tour</a></li>
                                                                    </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header has-specials">

<span class="listingFreshness">
				<span class="lastUpdated">
								<i class="rotateRightIcon" title="Last Updated"></i>
						<span>3 hrs Ago</span>
				</span>
</span>

                                <div class="specials" data-specials-label="1 Month Free">
                                    1 Month Free<i class="storyicon saleStoryIcon"></i>
                                    <span class="specialOfferTooltip">This property is offering 1 month free rent.</span>
                                </div>
                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,110 - 4,850</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">1-3 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>


                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:8442659153">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>844-265-9153</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-platinum" data-listingid="6y8v94s" data-url="https://www.apartments.com/harlow-hoboken-nj/6y8v94s/" data-ck="p2s139r">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/harlow-hoboken-nj/6y8v94s/">
                    
                    <div class="property-title" title="Harlow, Hoboken, NJ"><span class="js-placardTitle title">Harlow</span></div>
                    <div class="property-address js-url" title="1330 Willow Ave, Hoboken, NJ 07030">1330 Willow Ave, Hoboken, NJ 07030</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/harlow-hoboken-nj/6y8v94s/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="The Bozzuto Group" style="background-image: url(https://images1.apartments.com/i2/9dZAFlYvfgkw7kvg318zjTmviXLPJX8ZYB14Jl7Byzc/110/the-bozzuto-group-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">17</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/nVQsyGjauDVPKmp9G4rooenv2o8Sv62hiSJf8sYgdcY/115/harlow-hoboken-nj-building-photo.jpg" title="Building Photo - Harlow">
		</div>
	</div>
</div>

<div class="placardBanner">
        <button type="button" class="videoPlay" title="Watch Harlow Video" data-video="https://vapi.costargroup.com/video/play/4v9m9b?source=42" data-videokey="4v9m9b" data-datasource="42">
            <i class="playVideoPlacardIcon"></i>
        </button>
            <button type="button" class="virtualTour" title="See Harlow in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/harlow-hoboken-nj/6y8v94s/#photos">17 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/harlow-hoboken-nj/6y8v94s/#3dtours">Virtual Tour</a></li>
                                                                            <li><a href="https://www.apartments.com/harlow-hoboken-nj/6y8v94s/#videos">Videos</a></li>
                                </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header no-specials">

<span class="listingFreshness">
				<span class="new">
						<i class="alertLightningBoltIcon" title="New"></i>
						<span>New</span>
				</span>
</span>

                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,495 - 5,350</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">Studio - 3 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>


                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:8556686035">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>855-668-6035</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-platinum" data-listingid="n8lnc6n" data-url="https://www.apartments.com/artisan-series-hoboken-nj/n8lnc6n/" data-ck="p2s139r">
        <header class="placard-header has-logo">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/artisan-series-hoboken-nj/n8lnc6n/">
                    
                    <div class="property-title" title="Artisan Series, Hoboken, NJ"><span class="js-placardTitle title">Artisan Series</span></div>
                    <div class="property-address js-url" title="1100 Jefferson St, Hoboken, NJ 07030">1100 Jefferson St, Hoboken, NJ 07030</div>
                </a>
            </div>
                <div class="property-logo-wrapper ">
                    <a class="property-link js-url" href="https://www.apartments.com/artisan-series-hoboken-nj/n8lnc6n/">
                        <div class="property-logo-inner">
                            <div class="property-logo" role="img" aria-label="The Bozzuto Group" style="background-image: url(https://images1.apartments.com/i2/9dZAFlYvfgkw7kvg318zjTmviXLPJX8ZYB14Jl7Byzc/110/the-bozzuto-group-logo.png);"></div>
                        </div>
                    </a>
                </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">14</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/MWHFnivGaCPsymgMxhWS0Ou37u69ts4NPgzmPuyX-Kg/115/artisan-series-hoboken-nj-building-photo.jpg" title="Building Photo - Artisan Series">
		</div>
	</div>
</div>

<div class="placardBanner">
        <button type="button" class="videoPlay" title="Watch Artisan Series Video" data-video="https://vapi.costargroup.com/video/play/4v1q0v?source=42" data-videokey="4v1q0v" data-datasource="42">
            <i class="playVideoPlacardIcon"></i>
        </button>
            <button type="button" class="virtualTour" title="See Artisan Series in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/artisan-series-hoboken-nj/n8lnc6n/#photos">14 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/artisan-series-hoboken-nj/n8lnc6n/#3dtours">Virtual Tour</a></li>
                                                                            <li><a href="https://www.apartments.com/artisan-series-hoboken-nj/n8lnc6n/#videos">Videos</a></li>
                                </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header no-specials">

<span class="listingFreshness">
				<span class="new">
						<i class="alertLightningBoltIcon" title="New"></i>
						<span>New</span>
				</span>
</span>

                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$2,438 - 4,763</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">1-3 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>


                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:8557304826">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>855-730-4826</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>
<li class="mortar-wrapper">
    <article class="placard placard-option has-header js-platinum" data-listingid="cbtzdlf" data-url="https://www.apartments.com/204-grand-hoboken-nj/cbtzdlf/" data-ck="4sp81fh">
        <header class="placard-header ">
            <div class="property-information">
                <a class="property-link" href="https://www.apartments.com/204-grand-hoboken-nj/cbtzdlf/">
                    
                    <div class="property-title" title="204 Grand, Hoboken, NJ"><span class="js-placardTitle title">204 Grand</span></div>
                    <div class="property-address js-url" title="204 Grand St, Hoboken, NJ 07030">204 Grand St, Hoboken, NJ 07030</div>
                </a>
            </div>
                            <div class="favorite-wrapper">

<a href="javascript:void(0);" class="favoriteIcon neutral" data-liked-classes="liked" data-neutral-classes="neutral"></a>
                </div>
        </header>
        <section class="placard-content">
            <div class="content-inner">
                <div class="media-wrapper">
                    <div class="media-sizer"></div>
                    <div class="media-outer">
                        <div class="media-inner">
                            <div class="media">

	<div class="placardCarouselImgCount">
		<span class="js-spnImgNum">1</span> / <span class="js-spnImgCount">23</span>
	</div>
	<div class="galleryControl">
		<button type="button" class="imageCarouselLeftContainer">
			<i class="imageCarouselArrowLeftIcon"></i>
		</button>
		<button type="button" class="imageCarouselRightContainer">
			<i class="imageCarouselArrowRightIcon"></i>
		</button>
	</div>
<div class="imageContainer carousel slide" data-interval="false">
        <div class="carouselSpinner">
            <i class="aptsLogoMarkIcon rotate"></i>
        </div>
        <div class="fallbackSpinner">
            <i class="spinner"></i>
        </div>
    <div class="carouselInner">
		<div class="item active " data-image="https://images1.apartments.com/i2/hP58OxKWfOeKCUyZnLI99gmKmleJUvKe5olYgnzecRY/115/204-grand-hoboken-nj-building-photo.jpg" title="Building Photo - 204 Grand">
		</div>
	</div>
</div>

<div class="placardBanner">
            <button type="button" class="virtualTour" title="See 204 Grand in 3D">
            <span>3D Tours</span>
        </button>
</div>
                            </div>
                        </div>
                            <div class="mediaLinks">
                                <ul class="mediaLinksList">
                                        <li><a href="https://www.apartments.com/204-grand-hoboken-nj/cbtzdlf/#photos">23 Photos</a></li>
                                                                            <li><a href="https://www.apartments.com/204-grand-hoboken-nj/cbtzdlf/#3dtours">Virtual Tour</a></li>
                                                                    </ul>
                            </div>
                    </div>


                </div>

                <div class="property-info">
                    <div class="content-wrapper">
                        <div class="property-details-wrapper has-header no-specials">

<span class="listingFreshness">
				<span class="lastUpdated">
								<i class="rotateRightIcon" title="Last Updated"></i>
						<span>9 hrs Ago</span>
				</span>
</span>

                        </div>
                        <div class="price-wrapper">
                            <div class="price-range">$3,015 - 3,705</div>
                                                        </div>
                        <div class="property-information-wrapper">
                            <div class="bed-range">1-2 Bed</div>
                            <div class="availability">Avail. Now</div>
                        </div>


                        <div class="phone-wrapper">
                                <a class="phone-link js-phone" href="tel:8448969762">
                                    <i class="storyicon comMobileStoryIcon"></i>
                                    <span>844-896-9762</span>
                                </a>
                        </div>
                        <div class="property-actions">
                            <div class="actions-wrapper">
                                    <button class="checkAvailability btn">Email</button>
                                                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</li>    <li>
            <p class="searchResults">
                Showing Results 1 - 25,
                <span class="pageRange">Page 1 of 28</span>
            </p>
        <nav id="paging" class="paging seoVariant3" aria-label="Search Results">
            <ol>
                <li>
                    <a class="active" aria-label="Current Page" data-page="1">1</a>
                </li>
                        <li>
                            <a href="https://www.apartments.com/hoboken-nj/2/" data-page="2"> 2</a>
                        </li>
                        <li>
                            <a href="https://www.apartments.com/hoboken-nj/3/" data-page="3"> 3</a>
                        </li>
                        <li>
                            <a href="https://www.apartments.com/hoboken-nj/4/" data-page="4"> 4</a>
                        </li>
                        <li>
                            <a href="https://www.apartments.com/hoboken-nj/5/" data-page="5"> 5</a>
                        </li>
                                
                    <li>
                        <a class="next " aria-label="Next Page" href="javascript:void(0)" data-page="2">
                            <span class="pagingBtn">Next</span>
                        </a>
                    </li>
            </ol>
        </nav>
    </li>
    </ul>
</div>
